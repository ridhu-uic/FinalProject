# %%
import json

# Open the JSON file for reading
with open('Month_data/2019_1.json', 'r') as file:
    # Load the JSON data from the file
    data = json.load(file)

# Print the data to verify it was loaded correctly
print(data)
# Out:
# [{'fips': 1001, 'state': 'AL', 'area_name': 'Autauga County', 'flow': 3272425.0}, {'fips': 1003, 'state': 'AL', 'area_name': 'Baldwin County', 'flow': 13922857.0}, {'fips': 1005, 'state': 'AL', 'area_name': 'Barbour County', 'flow': 1332257.0}, {'fips': 1007, 'state': 'AL', 'area_name': 'Bibb County', 'flow': 1049003.0}, {'fips': 1009, 'state': 'AL', 'area_name': 'Blount County', 'flow': 2847060.0}, {'fips': 1011, 'state': 'AL', 'area_name': 'Bullock County', 'flow': 327555.0}, {'fips': 1013, 'state': 'AL', 'area_name': 'Butler County', 'flow': 1053965.0}, {'fips': 1015, 'state': 'AL', 'area_name': 'Calhoun County', 'flow': 7307025.0}, {'fips': 1017, 'state': 'AL', 'area_name': 'Chambers County', 'flow': 1531602.0}, {'fips': 1019, 'state': 'AL', 'area_name': 'Cherokee County', 'flow': 1208215.0}, {'fips': 1021, 'state': 'AL', 'area_name': 'Chilton County', 'flow': 2398681.0}, {'fips': 1023, 'state': 'AL', 'area_name': 'Choctaw County', 'flow': 547720.0}, {'fips': 1025, 'state': 'AL',
# ...

# %%
flow = []

# %%
for county in data:
    
    flow.append(county["flow"])

# %%
flow
# Out:
# [3272425.0,
#  13922857.0,
#  1332257.0,
#  1049003.0,
#  2847060.0,
#  327555.0,
#  1053965.0,
#  7307025.0,
#  1531602.0,
#  1208215.0,
#  2398681.0,
#  547720.0,
#  1374179.0,
#  568825.0,
#  673017.0,
#  3231302.0,
#  3655095.0,
#  506074.0,
#  386210.0,
#  2229885.0,
#  593190.0,
#  5742988.0,
#  2356380.0,
#  1920684.0,
#  3577542.0,
#  5222976.0,
#  2051355.0,
#  6349654.0,
#  908490.0,
#  1644170.0,
#  1364541.0,
#  253033.0,
#  605998.0,
#  792191.0,
#  8513253.0,
#  2786086.0,
#  45477692.0,
#  639995.0,
#  6803871.0,
#  1626388.0,
#  11660979.0,
#  5060194.0,
#  470715.0,
#  736018.0,
#  24541524.0,
#  983062.0,
#  1786663.0,
#  5894074.0,
#  26047260.0,
#  1042151.0,
#  14980730.0,
#  7434634.0,
#  389354.0,
#  792205.0,
#  2338443.0,
#  1061990.0,
#  2769518.0,
#  5121524.0,
#  14947196.0,
#  626392.0,
#  4200185.0,
#  2177117.0,
#  14736468.0,
#  4098160.0,
#  599415.0,
#  396782.0,
#  1184458.0,
#  54786.0,
#  154339.0,
#  14120336.0,
#  339803.0,
#  20183.0,
# ...

# %%
# !pip install matplotlib
# Out:
# ...
#      ---------------------------------------- 7.2/7.2 MB 2.8 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 2.5/2.5 MB 9.5 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 54.9/54.9 kB 3.0 MB/s eta 0:00:00
# ...
#      -------------------------------------- 965.4/965.4 kB 7.6 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 98.3/98.3 kB 5.9 MB/s eta 0:00:00
# ...
# [notice] A new release of pip is available: 23.0.1 -> 23.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import matplotlib
import matplotlib.pyplot as plt


# Plot the histogram
plt.hist(flow, bins=5)

# Add labels and title
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('Histogram of Values')

# Display the plot
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Generate 3000 random values between 1000 and 10000000
values = np.random.randint(1000, 10000000, size=3000)

# Define the number of bins and the range of values
num_bins = 20
value_range = (1000, 10000000000)

# Create the histogram bins
bins = np.logspace(np.log10(value_range[0]), np.log10(value_range[1]), num=num_bins)

# Plot the histogram
plt.hist(flow, bins=bins)

# Add labels and title
plt.xscale('log')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('Histogram of Values')

# Display the plot
plt.show()
