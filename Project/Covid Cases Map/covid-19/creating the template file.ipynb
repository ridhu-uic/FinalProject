# %%
import pandas as pd

# %%
import os
import json

# Get the absolute path to the current working directory
current_dir = os.path.abspath(os.getcwd())

# Construct the path to the JSON file relative to the current working directory
json_path = os.path.join(current_dir, '..',  'counties.json')

# Load the JSON file
with open(json_path) as f:
    data = json.load(f)

# %%
county_list=[]
for county in data["objects"]["counties"]["geometries"]:
    county_list.append(county["id"])

# %%
# Construct the path to the JSON file relative to the current working directory
json_path = os.path.join(current_dir, '..',  'he.json')

# Load the JSON file
with open(json_path) as f:
    data_he = json.load(f)

# %%
for values in data_he:
    values["flow"]=values.pop("bachelorsOrHigher")
    values["flow"]=0

# %%
with open('template_flow.json', 'w') as outfile:
    json.dump(data_he, outfile)

# %%
import os
import json

# Get the absolute path to the current working directory
current_dir = os.path.abspath(os.getcwd())

# Construct the path to the JSON file relative to the current working directory
json_path = os.path.join('template_flow.json')

# Load the JSON file
with open(json_path) as f:
    d = json.load(f)

# %%
          
for values in d:
    if values['flow']>0:
        print(values)

# %%
d
# Out:
# [{'fips': 1001, 'state': 'AL', 'area_name': 'Autauga County', 'flow': 0},
#  {'fips': 1003, 'state': 'AL', 'area_name': 'Baldwin County', 'flow': 0},
#  {'fips': 1005, 'state': 'AL', 'area_name': 'Barbour County', 'flow': 0},
#  {'fips': 1007, 'state': 'AL', 'area_name': 'Bibb County', 'flow': 0},
#  {'fips': 1009, 'state': 'AL', 'area_name': 'Blount County', 'flow': 0},
#  {'fips': 1011, 'state': 'AL', 'area_name': 'Bullock County', 'flow': 0},
#  {'fips': 1013, 'state': 'AL', 'area_name': 'Butler County', 'flow': 0},
#  {'fips': 1015, 'state': 'AL', 'area_name': 'Calhoun County', 'flow': 0},
#  {'fips': 1017, 'state': 'AL', 'area_name': 'Chambers County', 'flow': 0},
#  {'fips': 1019, 'state': 'AL', 'area_name': 'Cherokee County', 'flow': 0},
#  {'fips': 1021, 'state': 'AL', 'area_name': 'Chilton County', 'flow': 0},
#  {'fips': 1023, 'state': 'AL', 'area_name': 'Choctaw County', 'flow': 0},
#  {'fips': 1025, 'state': 'AL', 'area_name': 'Clarke County', 'flow': 0},
# ...
